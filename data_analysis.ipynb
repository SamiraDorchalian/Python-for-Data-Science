# %%
import numpy as np
import pandas as pd

# %%
sal = pd.read_csv("C:\\Users\\ziggurat\\Desktop\python for data science\\train.csv")
sal
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# C:\Users\ziggurat\AppData\Local\Temp\ipykernel_9044\461554544.py:1: SyntaxWarning: invalid escape sequence '\p'
#   sal = pd.read_csv("C:\\Users\\ziggurat\\Desktop\python for data science\\train.csv")
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 1          2  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 2          3  CA-2017-138688  12/06/2017  16/06/2017    Second Class
# 3          4  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# 4          5  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# ...      ...             ...         ...         ...             ...
# 9795    9796  CA-2017-125920  21/05/2017  28/05/2017  Standard Class
# 9796    9797  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# ...

# %%
sal.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
sal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9800 non-null   int64
#  1   Order ID       9800 non-null   object
#  2   Order Date     9800 non-null   object
#  3   Ship Date      9800 non-null   object
#  4   Ship Mode      9800 non-null   object
#  5   Customer ID    9800 non-null   object
#  6   Customer Name  9800 non-null   object
#  7   Segment        9800 non-null   object
#  8   Country        9800 non-null   object
#  9   City           9800 non-null   object
#  10  State          9800 non-null   object
#  11  Postal Code    9789 non-null   float64
#  12  Region         9800 non-null   object
#  13  Product ID     9800 non-null   object
#  14  Category       9800 non-null   object
#  15  Sub-Category   9800 non-null   object
#  16  Product Name   9800 non-null   object
# ...

# %%
sal.shape
# Out:
# (9800, 18)

# %%
sal.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales'],
#       dtype='object')

# %% [markdown]
# درمورد مفهوم هرکدام از داده ها گفتگو کنید

# %%
sal.describe()
# Out:
#             Row ID   Postal Code         Sales
# count  9800.000000   9789.000000   9800.000000
# mean   4900.500000  55273.322403    230.769059
# std    2829.160653  32041.223413    626.651875
# min       1.000000   1040.000000      0.444000
# 25%    2450.750000  23223.000000     17.248000
# 50%    4900.500000  58103.000000     54.490000
# 75%    7350.250000  90008.000000    210.605000
# max    9800.000000  99301.000000  22638.480000

# %% [markdown]
# کمترین ، بیشترین و میانگین فروش را محاسبه کنید

# %%
sal['Sales'].min()
# Out:
# 0.444

# %%
sal['Sales'].max()
# Out:
# 22638.48

# %%
sal['Sales'].mean()
# Out:
# 230.7690594591837

# %% [markdown]
# این فروشگاه از چند شهر متنوع سفارش گرفته است؟

# %%
sal['City'].unique()
# Out:
# array(['Henderson', 'Los Angeles', 'Fort Lauderdale', 'Concord',
#        'Seattle', 'Fort Worth', 'Madison', 'West Jordan', 'San Francisco',
#        'Fremont', 'Philadelphia', 'Orem', 'Houston', 'Richardson',
#        'Naperville', 'Melbourne', 'Eagan', 'Westland', 'Dover',
#        'New Albany', 'New York City', 'Troy', 'Chicago', 'Gilbert',
#        'Springfield', 'Jackson', 'Memphis', 'Decatur', 'Durham',
#        'Columbia', 'Rochester', 'Minneapolis', 'Portland', 'Saint Paul',
#        'Aurora', 'Charlotte', 'Orland Park', 'Urbandale', 'Columbus',
#        'Bristol', 'Wilmington', 'Bloomington', 'Phoenix', 'Roseville',
#        'Independence', 'Pasadena', 'Newark', 'Franklin', 'Scottsdale',
#        'San Jose', 'Edmond', 'Carlsbad', 'San Antonio', 'Monroe',
#        'Fairfield', 'Grand Prairie', 'Redlands', 'Hamilton', 'Westfield',
#        'Akron', 'Denver', 'Dallas', 'Whittier', 'Saginaw', 'Medina',
#        'Dublin', 'Detroit', 'Tampa', 'Santa Clara', 'Lakeville',
# ...

# %%
sal['City'].nunique()
# Out:
# 529

# %% [markdown]
# پنج تاریخی که این فروشگاه بیشترین سفارش رو گرفته

# %% [markdown]
# سفارشاتی که مبلغ فروش انها بیشتر از 800 دلار است را فیلتر کنید

# %%
sal['Sales'] > 800
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 9795    False
# 9796    False
# 9797    False
# 9798    False
# 9799    False
# Name: Sales, Length: 9800, dtype: bool

# %%
sal[sal['Sales'] > 800]
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 3          4  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# 7          8  CA-2015-115812  09/06/2015  14/06/2015  Standard Class
# 10        11  CA-2015-115812  09/06/2015  14/06/2015  Standard Class
# 11        12  CA-2015-115812  09/06/2015  14/06/2015  Standard Class
# 24        25  CA-2016-106320  25/09/2016  30/09/2016  Standard Class
# ...      ...             ...         ...         ...             ...
# 9734    9735  CA-2015-114321  20/08/2015  25/08/2015  Standard Class
# 9741    9742  CA-2016-117086  08/11/2016  12/11/2016  Standard Class
# 9759    9760  CA-2017-146913  31/10/2017  05/11/2017  Standard Class
# 9774    9775  CA-2015-169019  26/07/2015  30/07/2015  Standard Class
# 9787    9788  CA-2018-144491  27/03/2018  01/04/2018  Standard Class
#
#      Customer ID    Customer Name    Segment        Country             City  \
# ...

# %% [markdown]
# بیشترین و کمترین فروش مربوط به کدام کشور است

# %%
sal[sal['Sales'] == sal['Sales'].max()]
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 2697    2698  CA-2015-145317  18/03/2015  23/03/2015  Standard Class
#
#      Customer ID Customer Name      Segment        Country          City  \
# 2697    SM-20320   Sean Miller  Home Office  United States  Jacksonville
#
#         State  Postal Code Region       Product ID    Category Sub-Category  \
# 2697  Florida      32216.0  South  TEC-MA-10002412  Technology     Machines
#
#                                            Product Name     Sales
# 2697  Cisco TelePresence System EX90 Videoconferenci...  22638.48

# %%
sal[sal['Sales'] == sal['Sales'].max()]['City']
# Out:
# 2697    Jacksonville
# Name: City, dtype: object

# %%
sal[sal['Sales'] == sal['Sales'].min()]
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 4101    4102  US-2018-102288  19/06/2018  23/06/2018  Standard Class
#
#      Customer ID     Customer Name   Segment        Country     City  State  \
# 4101    ZC-21910  Zuschuss Carroll  Consumer  United States  Houston  Texas
#
#       Postal Code   Region       Product ID         Category Sub-Category  \
# 4101      77095.0  Central  OFF-AP-10002906  Office Supplies   Appliances
#
#                                            Product Name  Sales
# 4101  Hoover Replacement Belt for Commercial Guardsm...  0.444

# %%
sal[sal['Sales'] == sal['Sales'].min()]['City']
# Out:
# 4101    Houston
# Name: City, dtype: object

# %%
sal[sal['Sales'] == sal['Sales'].min()]['Country']
# Out:
# 4101    United States
# Name: Country, dtype: object

# %%
sal[sal['Sales'] == sal['Sales'].max()]['Country']
# Out:
# 2697    United States
# Name: Country, dtype: object

# %%
sal['City'].value_counts()
# Out:
# City
# New York City    891
# Los Angeles      728
# Philadelphia     532
# San Francisco    500
# Seattle          426
#                 ...
# San Mateo          1
# Cheyenne           1
# Conway             1
# Melbourne          1
# Springdale         1
# Name: count, Length: 529, dtype: int64

# %%
sal['City'].value_counts().head()
# Out:
# City
# New York City    891
# Los Angeles      728
# Philadelphia     532
# San Francisco    500
# Seattle          426
# Name: count, dtype: int64

# %% [markdown]
# سفارشاتی که در شهر لس انجلس انجام شده را فیلتر کنید و بگویید در مجموع این فروشگاه چقدر فروش در این شهر داشته؟

# %%
sal[sal['City'] == "Los Angeles"]
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 2          3  CA-2017-138688  12/06/2017  16/06/2017    Second Class
# 5          6  CA-2015-115812  09/06/2015  14/06/2015  Standard Class
# 6          7  CA-2015-115812  09/06/2015  14/06/2015  Standard Class
# 7          8  CA-2015-115812  09/06/2015  14/06/2015  Standard Class
# 8          9  CA-2015-115812  09/06/2015  14/06/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9739    9740  CA-2018-129294  16/03/2018  21/03/2018  Standard Class
# 9740    9741  CA-2018-129294  16/03/2018  21/03/2018  Standard Class
# 9745    9746  CA-2018-137505  24/11/2018  24/11/2018        Same Day
# 9746    9747  CA-2018-137505  24/11/2018  24/11/2018        Same Day
# 9764    9765  CA-2015-123855  18/06/2015  23/06/2015  Standard Class
#
#      Customer ID    Customer Name    Segment        Country         City  \
# ...

# %%
sal[sal['City'] == "Los Angeles"].sum()
# Out:
# Row ID                                                     3596521
# Order ID         CA-2017-138688CA-2015-115812CA-2015-115812CA-2...
# Order Date       12/06/201709/06/201509/06/201509/06/201509/06/...
# Ship Date        16/06/201714/06/201514/06/201514/06/201514/06/...
# Ship Mode        Second ClassStandard ClassStandard ClassStanda...
# Customer ID      DV-13045BH-11710BH-11710BH-11710BH-11710BH-117...
# Customer Name    Darrin Van HuffBrosina HoffmanBrosina HoffmanB...
# Segment          CorporateConsumerConsumerConsumerConsumerConsu...
# Country          United StatesUnited StatesUnited StatesUnited ...
# City             Los AngelesLos AngelesLos AngelesLos AngelesLo...
# State            CaliforniaCaliforniaCaliforniaCaliforniaCalifo...
# Postal Code                                             65542378.0
# Region           WestWestWestWestWestWestWestWestWestWestWestWe...
# Product ID       OFF-LA-10000240FUR-FU-10001487OFF-AR-10002833T...
# ...

# %% [markdown]
# ارسال شده اند را فیلتر کنید"California"در ایالت  "San Francisco"تمام سفارش هایی که به شهر

# %%
sal[(sal['City'] == 'San Francisco') & (sal['State'] == 'California')]
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 18        19  CA-2015-143336  27/08/2015  01/09/2015    Second Class
# 19        20  CA-2015-143336  27/08/2015  01/09/2015    Second Class
# 20        21  CA-2015-143336  27/08/2015  01/09/2015    Second Class
# 81        82  CA-2015-139451  12/10/2015  16/10/2015  Standard Class
# 82        83  CA-2015-139451  12/10/2015  16/10/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9694    9695  CA-2018-130148  24/09/2018  28/09/2018    Second Class
# 9705    9706  CA-2018-125990  19/10/2018  23/10/2018  Standard Class
# 9715    9716  CA-2017-116379  07/11/2017  12/11/2017  Standard Class
# 9759    9760  CA-2017-146913  31/10/2017  05/11/2017  Standard Class
# 9768    9769  CA-2018-142328  07/12/2018  14/12/2018  Standard Class
#
#      Customer ID       Customer Name      Segment        Country  \
# 18      ZD-21925  Zuschuss Donatelli     Consumer  United States
# ...

# %% [markdown]
# تمام سفارشاتی که در سال 2017 ثبت شده اند را فیلتر کنید

# %%
sal['Order Date'] == pd.to_datetime(sal["Order Date"], format= "%d/%m/%Y")
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9795     True
# 9796    False
# 9797    False
# 9798    False
# 9799    False
# Name: Order Date, Length: 9800, dtype: bool

# %% [markdown]
# # group by

# %% [markdown]
# تعداد کل سفارشات برای هر دسته محصول را پیدا کنید.

# %%
sal.groupby("Category")["Order ID"].count()
# Out:
# Category
# Furniture          2078
# Office Supplies    5909
# Technology         1813
# Name: Order ID, dtype: int64

# %% [markdown]
# تعداد کل سفارشات برای هر دسته محصول را محاسبه کنید

# %%
sal.groupby('Category')['Sales'].agg(min)
# Out:
# C:\Users\ziggurat\AppData\Local\Temp\ipykernel_9044\1579196749.py:1: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   sal.groupby('Category')['Sales'].agg(min)
# Category
# Furniture          1.892
# Office Supplies    0.444
# Technology         0.990
# Name: Sales, dtype: float64

# %% [markdown]
# مجموع فروش برای هر دسته محصول را محاسبه کنید

# %%
sal.groupby("Category")["Sales"].sum()
# Out:
# Category
# Furniture          728658.5757
# Office Supplies    705422.3340
# Technology         827455.8730
# Name: Sales, dtype: float64

# %% [markdown]
# بیشترین و کمترین فروش برای هر دسته از محصول رو محاسبه کنید

# %%
sal.groupby("Category")["Sales"].agg(min)
# Out:
# C:\Users\ziggurat\AppData\Local\Temp\ipykernel_9044\2869343820.py:1: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   sal.groupby("Category")["Sales"].agg(min)
# Category
# Furniture          1.892
# Office Supplies    0.444
# Technology         0.990
# Name: Sales, dtype: float64
